# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pathlib
import tensorflow as tf
import itertools
import sklearn
# %matplotlib inline

from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report 
from sklearn import datasets 
from tensorflow.keras import models, layers
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, MaxPool2D,BatchNormalization
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from tensorflow import keras
from keras import Sequential
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
        'DERMNET/Selected Dataset (Dermnet)/train',
        target_size=(32, 32),
        batch_size=8,
)

test_data = test_datagen.flow_from_directory(
        'DERMNET/Selected Dataset (Dermnet)/test',
        target_size=(32, 32),
        batch_size=8,
        )
# Out:
# Found 3943 images belonging to 4 classes.
# Found 1089 images belonging to 4 classes.

# %%
tf.keras.preprocessing.image.DirectoryIterator(
    "DERMNET/Selected Dataset (Dermnet)",
    ImageDataGenerator,
    target_size=(256, 256),
    color_mode='rgb',
    classes=None,
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    seed=None,
    data_format=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False,
    dtype=None
)
# Out:
# Found 5032 images belonging to 2 classes.

# %%
#Set all the Constants
batchSize = 32
imageSize = 256
channels=4
epoch = 50

# %%
#Import data into tensorflow dataset object()
imageDataset = tf.keras.preprocessing.image_dataset_from_directory(
    "DERMNET/Selected Dataset (Dermnet)", seed=123, shuffle=True, image_size=(imageSize,imageSize), batch_size=batchSize
)
# Out:
# Found 5032 files belonging to 2 classes.

# %%
#Check for dataset classes
classNames = imageDataset.class_names
classNames
# Out:
# ['test', 'train']

# %%
pre_trained_model = VGG19(input_shape=(256, 256, 3), include_top=False, weights="imagenet")

# %%
for layer in pre_trained_model.layers:
    print(layer.name)
    layer.trainable = False
    
print(len(pre_trained_model.layers))
# Out:
# input_1
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_conv4
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_conv4
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_conv4
# block5_pool
# 22

# %%
last_layer = pre_trained_model.get_layer('block5_pool')
print('last layer output shape:', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape: (None, 8, 8, 512)

# %%
# Flatten the output layer to 1 dimension
x = layers.GlobalMaxPooling2D()(last_output)
# Add a fully connected layer with 512 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)
# Add a dropout rate of 0.5
x = layers.Dropout(0.5)(x)
# Add a final sigmoid layer for classification
x = layers.Dense(4)(x)

# Configure and compile the model
model = Model(pre_trained_model.input, x)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
        train_data,
        validation_data=train_data,
        verbose=1,
        epochs=epoch,
       )
# Out:
# Epoch 1/50
# 493/493 [==============================] - 71s 142ms/step - loss: 3.6211 - accuracy: 0.3206 - val_loss: 3.5453 - val_accuracy: 0.3117
# Epoch 2/50
# 493/493 [==============================] - 73s 149ms/step - loss: 3.8771 - accuracy: 0.3338 - val_loss: 3.8562 - val_accuracy: 0.2856
# Epoch 3/50
# 493/493 [==============================] - 74s 150ms/step - loss: 3.8516 - accuracy: 0.2655 - val_loss: 3.8562 - val_accuracy: 0.3015
# Epoch 4/50
# 493/493 [==============================] - 86s 175ms/step - loss: 3.8159 - accuracy: 0.2934 - val_loss: 3.6455 - val_accuracy: 0.3546
# Epoch 5/50
# 493/493 [==============================] - 97s 196ms/step - loss: 3.8219 - accuracy: 0.2658 - val_loss: 3.8562 - val_accuracy: 0.2387
# Epoch 6/50
# 493/493 [==============================] - 92s 187ms/step - loss: 3.8515 - accuracy: 0.2995 - val_loss: 3.8543 - val_accuracy: 0.2648
# Epoch 7/50
# 493/493 [==============================] - 90s 182ms/step - loss: 3.8398 - accuracy: 0.3010 - val_loss: 3.8543 - val_accuracy: 0.2678
# Epoch 8/50
# 493/493 [==============================] - 89s 181ms/step - loss: 3.8384 - accuracy: 0.3005 - val_loss: 3.6299 - val_accuracy: 0.3454
# Epoch 9/50
# 493/493 [==============================] - 89s 181ms/step - loss: 3.7719 - accuracy: 0.3292 - val_loss: 3.8429 - val_accuracy: 0.2381
# Epoch 10/50
# 493/493 [==============================] - 90s 182ms/step - loss: 3.8325 - accuracy: 0.2780 - val_loss: 3.7253 - val_accuracy: 0.3477
# Epoch 11/50
# 493/493 [==============================] - 90s 182ms/step - loss: 3.7032 - accuracy: 0.3746 - val_loss: 3.7038 - val_accuracy: 0.4382
# Epoch 12/50
# 493/493 [==============================] - 93s 188ms/step - loss: 3.7522 - accuracy: 0.3989 - val_loss: 3.6152 - val_accuracy: 0.4284
# Epoch 13/50
# 493/493 [==============================] - 93s 188ms/step - loss: 3.7268 - accuracy: 0.4131 - val_loss: 3.7560 - val_accuracy: 0.4142
# Epoch 14/50
# 493/493 [==============================] - 90s 182ms/step - loss: 3.7050 - accuracy: 0.4038 - val_loss: 3.6477 - val_accuracy: 0.3850
# Epoch 15/50
# 493/493 [==============================] - 89s 180ms/step - loss: 3.8005 - accuracy: 0.3647 - val_loss: 3.7727 - val_accuracy: 0.4202
# Epoch 16/50
# 493/493 [==============================] - 93s 189ms/step - loss: 3.7765 - accuracy: 0.3779 - val_loss: 3.7722 - val_accuracy: 0.3454
# Epoch 17/50
# 493/493 [==============================] - 89s 181ms/step - loss: 3.6736 - accuracy: 0.3393 - val_loss: 3.6834 - val_accuracy: 0.3381
# Epoch 36/50
# 493/493 [==============================] - 89s 180ms/step - loss: 3.6834 - accuracy: 0.3330 - val_loss: 3.6195 - val_accuracy: 0.3604
# Epoch 37/50
# 493/493 [==============================] - 97s 197ms/step - loss: 3.6787 - accuracy: 0.3523 - val_loss: 3.6368 - val_accuracy: 0.3561
# Epoch 38/50
# 493/493 [==============================] - 89s 181ms/step - loss: 3.6586 - accuracy: 0.3411 - val_loss: 3.6475 - val_accuracy: 0.3525
# Epoch 39/50
# 493/493 [==============================] - 89s 180ms/step - loss: 3.6722 - accuracy: 0.3442 - val_loss: 3.6317 - val_accuracy: 0.3594
# Epoch 40/50
# 493/493 [==============================] - 90s 182ms/step - loss: 3.6776 - accuracy: 0.3480 - val_loss: 3.7089 - val_accuracy: 0.3396
# Epoch 41/50
# 493/493 [==============================] - 95s 192ms/step - loss: 3.6844 - accuracy: 0.3360 - val_loss: 3.6664 - val_accuracy: 0.3434
# Epoch 42/50
# 493/493 [==============================] - 100s 202ms/step - loss: 3.6834 - accuracy: 0.3340 - val_loss: 3.6749 - val_accuracy: 0.3360
# Epoch 43/50
# 493/493 [==============================] - 90s 182ms/step - loss: 3.6812 - accuracy: 0.3436 - val_loss: 3.6199 - val_accuracy: 0.3715
# Epoch 44/50
# 493/493 [==============================] - 89s 180ms/step - loss: 3.6551 - accuracy: 0.3480 - val_loss: 3.6488 - val_accuracy: 0.3675
# Epoch 45/50
# 493/493 [==============================] - 88s 179ms/step - loss: 3.6974 - accuracy: 0.3360 - val_loss: 3.6838 - val_accuracy: 0.3345
# Epoch 46/50
# 493/493 [==============================] - 88s 178ms/step - loss: 3.6616 - accuracy: 0.3401 - val_loss: 3.6345 - val_accuracy: 0.3581
# Epoch 47/50
# 493/493 [==============================] - 90s 183ms/step - loss: 3.6450 - accuracy: 0.3492 - val_loss: 3.6334 - val_accuracy: 0.3551
# Epoch 48/50
# 493/493 [==============================] - 91s 185ms/step - loss: 3.6840 - accuracy: 0.3353 - val_loss: 3.7047 - val_accuracy: 0.3244
# Epoch 49/50
# 493/493 [==============================] - 89s 180ms/step - loss: 3.7046 - accuracy: 0.3264 - val_loss: 3.6668 - val_accuracy: 0.3358
# Epoch 50/50
# 493/493 [==============================] - 93s 189ms/step - loss: 3.6778 - accuracy: 0.3576 - val_loss: 3.6308 - val_accuracy: 0.3563

# %%
for layer in pre_trained_model.layers:
    layer.trainable = True

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 20,289,092
# Trainable params: 20,289,092
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_val, acc_val = model.evaluate(train_data, verbose=1)
print("Validation: accuracy = %f  ;  loss_v = %f" % (acc_val, loss_val))
# Out:
# 493/493 [==============================] - 48s 95ms/step - loss: 3.6433 - accuracy: 0.3528
# Validation: accuracy = 0.352777  ;  loss_v = 3.643347

# %%
loss_test, acc_test = model.evaluate(test_data, verbose=1)
print("Test: accuracy = %f  ;  loss = %f" % (acc_test, loss_test))
# Out:
# 137/137 [==============================] - 13s 96ms/step - loss: 3.6707 - accuracy: 0.4123
# Test: accuracy = 0.412305  ;  loss = 3.670689

# %%
yTrue = test_data.classes

# %%
classes_ = ['Acne', 'Eczema', 'Melanoma', 'Psoriasis']

# Generate the confusion matrix for the model
y_pred = np.argmax(model.predict(test_data), axis=-1)
conf_mat = confusion_matrix(yTrue, y_pred, labels=range(len(classes_)))

group_names = ['True Acne','False Eczema','False Melanoma','False Psoriasis',
               'False Acne','True Eczema','False Melanoma','False Psoriasis',
               'False Acne','False Eczema','True Melanoma','False Psoriasis',
               'False Acne','False Eczema','False Melanoma','True Psoriasis']

group_counts = ["{0:0.0f}".format(value) for value in
                conf_mat.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     conf_mat.flatten()/np.sum(conf_mat)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(len(classes_),len(classes_))

ax = sns.heatmap(conf_mat, annot=labels, yticklabels=classes_, xticklabels=classes_, fmt='', cmap='OrRd')
ax.set(title='Confusion Matrix', xlabel='Predicted Diseases', ylabel='Actual Diseases')
ax.plot()
# Out:
# 137/137 [==============================] - 12s 84ms/step
# []

# %%
report = classification_report(yTrue, y_pred, target_names=classes_)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         Acne       0.29      0.71      0.41       312
#       Eczema       0.29      0.29      0.29       309
#     Melanoma       0.00      0.00      0.00       116
#    Psoriasis       0.50      0.00      0.01       352
#
#     accuracy                           0.29      1089
#    macro avg       0.27      0.25      0.18      1089
# weighted avg       0.33      0.29      0.20      1089

# %%
accuracy = history.history['accuracy']
validationAccuracy = history.history['val_accuracy']

loss = history.history['loss']
validationLoss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(epoch), accuracy, label='Training Accuracy')
plt.plot(range(epoch), validationAccuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(epoch), loss, label='Training Loss')
plt.plot(range(epoch), validationLoss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model_version=max([int(i) for i in os.listdir("../skinDiseaseDetection/models") + [1]])
model.save(f"../skinDiseaseDetection/models/{model_version}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17816\3930693720.py in <module>
# ----> 1 model_version=max([int(i) for i in os.listdir("../skinDiseaseDetection/models") + [1]])
#       2 model.save(f"../skinDiseaseDetection/models/{model_version}")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../skinDiseaseDetection/models'

# %%
model.save("../modelVGG.h5")
