# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pathlib
import tensorflow as tf
import itertools
import sklearn
# %matplotlib inline

from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report 
from sklearn import datasets 
from tensorflow.keras import models, layers
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, MaxPool2D,BatchNormalization
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from tensorflow import keras
from keras import Sequential
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
        'SKINDISEASE DATASET',
        target_size=(32, 32),
        batch_size=8,
)

test_data = test_datagen.flow_from_directory(
        'SKINDISEASE DATASET',
        target_size=(32, 32),
        batch_size=8,
        )
# Out:
# Found 1400 images belonging to 4 classes.
# Found 1400 images belonging to 4 classes.

# %%
tf.keras.preprocessing.image.DirectoryIterator(
    "SKINDISEASE DATASET",
    ImageDataGenerator,
    target_size=(256, 256),
    color_mode='rgb',
    classes=None,
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    seed=None,
    data_format=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False,
    dtype=None
)
# Out:
# Found 1400 images belonging to 4 classes.

# %%
#Set all the Constants
batchSize = 32
imageSize = 256
channels=3
epoch = 50

# %%
#Import data into tensorflow dataset object()
imageDataset = tf.keras.preprocessing.image_dataset_from_directory(
    "SKINDISEASE DATASET", seed=123, shuffle=True, image_size=(imageSize,imageSize), batch_size=batchSize
)
# Out:
# Found 1400 files belonging to 4 classes.

# %%
#Check for dataset classes
classNames = imageDataset.class_names
classNames
# Out:
# ['Acne and Rosacea',
#  'Eczema',
#  'Melanoma Skin Cancer Nevi and Moles',
#  'Psoriasis']

# %%
pre_trained_model = VGG19(input_shape=(256, 256, 3), include_top=False, weights="imagenet")

# %%
for layer in pre_trained_model.layers:
    print(layer.name)
    layer.trainable = False
    
print(len(pre_trained_model.layers))
# Out:
# input_1
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_conv4
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_conv4
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_conv4
# block5_pool
# 22

# %%
last_layer = pre_trained_model.get_layer('block5_pool')
print('last layer output shape:', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape: (None, 8, 8, 512)

# %%
# Flatten the output layer to 1 dimension
x = layers.GlobalMaxPooling2D()(last_output)
# Add a fully connected layer with 512 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)
# Add a dropout rate of 0.5
x = layers.Dropout(0.5)(x)
# Add a final sigmoid layer for classification
x = layers.Dense(4)(x)

# Configure and compile the model
model = Model(pre_trained_model.input, x)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
        train_data,
        validation_data=train_data,
        verbose=1,
        epochs=epoch,
       )
# Out:
# Epoch 1/50
# 175/175 [==============================] - 47s 257ms/step - loss: 3.7692 - accuracy: 0.3136 - val_loss: 3.3414 - val_accuracy: 0.3536
# Epoch 2/50
# 175/175 [==============================] - 46s 261ms/step - loss: 3.7151 - accuracy: 0.3129 - val_loss: 3.4537 - val_accuracy: 0.2943
# Epoch 3/50
# 175/175 [==============================] - 44s 251ms/step - loss: 3.4805 - accuracy: 0.3493 - val_loss: 3.7347 - val_accuracy: 0.4621
# Epoch 4/50
# 175/175 [==============================] - 44s 250ms/step - loss: 3.5778 - accuracy: 0.3500 - val_loss: 3.3361 - val_accuracy: 0.3114
# Epoch 5/50
# 175/175 [==============================] - 51s 293ms/step - loss: 3.4578 - accuracy: 0.3429 - val_loss: 3.3481 - val_accuracy: 0.3521
# Epoch 6/50
# 175/175 [==============================] - 113s 646ms/step - loss: 3.4035 - accuracy: 0.3571 - val_loss: 3.2367 - val_accuracy: 0.3621
# Epoch 7/50
# 175/175 [==============================] - 232s 1s/step - loss: 3.3518 - accuracy: 0.3600 - val_loss: 3.2237 - val_accuracy: 0.3864
# Epoch 8/50
# 175/175 [==============================] - 225s 1s/step - loss: 3.5399 - accuracy: 0.3950 - val_loss: 3.7199 - val_accuracy: 0.2521
# Epoch 9/50
# 175/175 [==============================] - 228s 1s/step - loss: 3.8623 - accuracy: 0.3071 - val_loss: 3.8562 - val_accuracy: 0.3221
# Epoch 10/50
# 175/175 [==============================] - 243s 1s/step - loss: 3.8404 - accuracy: 0.3514 - val_loss: 3.8562 - val_accuracy: 0.3736
# Epoch 11/50
# 175/175 [==============================] - 237s 1s/step - loss: 3.6705 - accuracy: 0.3929 - val_loss: 3.4562 - val_accuracy: 0.4371
# Epoch 12/50
# 175/175 [==============================] - 218s 1s/step - loss: 3.6055 - accuracy: 0.3957 - val_loss: 3.6906 - val_accuracy: 0.4479
# Epoch 13/50
# 175/175 [==============================] - 238s 1s/step - loss: 3.5254 - accuracy: 0.4050 - val_loss: 3.4367 - val_accuracy: 0.4057
# Epoch 14/50
# 175/175 [==============================] - 225s 1s/step - loss: 3.6434 - accuracy: 0.3650 - val_loss: 3.3022 - val_accuracy: 0.3493
# Epoch 15/50
# 175/175 [==============================] - 225s 1s/step - loss: 3.5086 - accuracy: 0.3686 - val_loss: 3.4496 - val_accuracy: 0.4321
# Epoch 16/50
# 175/175 [==============================] - 222s 1s/step - loss: 3.5445 - accuracy: 0.3986 - val_loss: 3.4040 - val_accuracy: 0.4171
# Epoch 17/50
# 175/175 [==============================] - 226s 1s/step - loss: 3.6528 - accuracy: 0.3586 - val_loss: 3.2662 - val_accuracy: 0.3814
# Epoch 18/50
# 175/175 [==============================] - 213s 1s/step - loss: 3.5161 - accuracy: 0.3886 - val_loss: 3.8511 - val_accuracy: 0.4007
# Epoch 19/50
# 175/175 [==============================] - 55s 317ms/step - loss: 3.8209 - accuracy: 0.3564 - val_loss: 3.8535 - val_accuracy: 0.4236
# Epoch 20/50
# 175/175 [==============================] - 61s 350ms/step - loss: 3.8046 - accuracy: 0.3707 - val_loss: 3.8288 - val_accuracy: 0.4721
# Epoch 21/50
# 175/175 [==============================] - 70s 403ms/step - loss: 3.7674 - accuracy: 0.3843 - val_loss: 3.7731 - val_accuracy: 0.5214
# Epoch 22/50
# 175/175 [==============================] - 56s 319ms/step - loss: 3.6877 - accuracy: 0.3864 - val_loss: 3.7964 - val_accuracy: 0.4543
# Epoch 23/50
# 175/175 [==============================] - 68s 388ms/step - loss: 3.7419 - accuracy: 0.3729 - val_loss: 3.8559 - val_accuracy: 0.2943
# Epoch 24/50
# 175/175 [==============================] - 65s 370ms/step - loss: 4.8754 - accuracy: 0.2836 - val_loss: 5.0084 - val_accuracy: 0.2900
# Epoch 25/50
# 175/175 [==============================] - 57s 324ms/step - loss: 4.4153 - accuracy: 0.3314 - val_loss: 3.8659 - val_accuracy: 0.3236
# Epoch 26/50
# 175/175 [==============================] - 55s 314ms/step - loss: 3.7111 - accuracy: 0.3793 - val_loss: 3.2912 - val_accuracy: 0.3764
# Epoch 27/50
# 175/175 [==============================] - 56s 318ms/step - loss: 3.5850 - accuracy: 0.3921 - val_loss: 3.2335 - val_accuracy: 0.4000
# Epoch 28/50
# 175/175 [==============================] - 54s 311ms/step - loss: 3.6819 - accuracy: 0.3800 - val_loss: 3.3314 - val_accuracy: 0.3836
# Epoch 29/50
# 175/175 [==============================] - 52s 299ms/step - loss: 3.5536 - accuracy: 0.4007 - val_loss: 3.5894 - val_accuracy: 0.4957
# Epoch 30/50
# 175/175 [==============================] - 53s 303ms/step - loss: 3.6483 - accuracy: 0.3914 - val_loss: 3.3821 - val_accuracy: 0.4600
# Epoch 31/50
# 175/175 [==============================] - 51s 290ms/step - loss: 3.5289 - accuracy: 0.4000 - val_loss: 3.3117 - val_accuracy: 0.4314
# Epoch 32/50
# 175/175 [==============================] - 50s 285ms/step - loss: 3.6601 - accuracy: 0.3800 - val_loss: 3.3171 - val_accuracy: 0.4250
# Epoch 33/50
# 175/175 [==============================] - 51s 292ms/step - loss: 3.5665 - accuracy: 0.4129 - val_loss: 3.3357 - val_accuracy: 0.4050
# Epoch 34/50
# 175/175 [==============================] - 67s 383ms/step - loss: 3.5548 - accuracy: 0.3836 - val_loss: 3.4933 - val_accuracy: 0.3757
# Epoch 35/50
# 175/175 [==============================] - 55s 316ms/step - loss: 3.5794 - accuracy: 0.3900 - val_loss: 3.3418 - val_accuracy: 0.4771
# Epoch 36/50
# 175/175 [==============================] - 52s 299ms/step - loss: 3.5184 - accuracy: 0.4164 - val_loss: 3.2879 - val_accuracy: 0.4693
# Epoch 37/50
# 175/175 [==============================] - 56s 321ms/step - loss: 3.4758 - accuracy: 0.3900 - val_loss: 3.3218 - val_accuracy: 0.4736
# Epoch 38/50
# 175/175 [==============================] - 54s 308ms/step - loss: 3.4597 - accuracy: 0.4193 - val_loss: 3.2693 - val_accuracy: 0.4643
# Epoch 39/50
# 175/175 [==============================] - 53s 303ms/step - loss: 3.5277 - accuracy: 0.4057 - val_loss: 3.4172 - val_accuracy: 0.4879
# Epoch 40/50
# 175/175 [==============================] - 55s 316ms/step - loss: 3.5149 - accuracy: 0.4100 - val_loss: 3.3242 - val_accuracy: 0.4521
# Epoch 41/50
# 175/175 [==============================] - 53s 303ms/step - loss: 3.5392 - accuracy: 0.4007 - val_loss: 3.2391 - val_accuracy: 0.4671
# Epoch 42/50
# 175/175 [==============================] - 53s 305ms/step - loss: 3.4669 - accuracy: 0.4150 - val_loss: 3.2528 - val_accuracy: 0.4586
# Epoch 43/50
# 175/175 [==============================] - 55s 315ms/step - loss: 3.4551 - accuracy: 0.4421 - val_loss: 3.2495 - val_accuracy: 0.4329
# Epoch 44/50
# 175/175 [==============================] - 52s 297ms/step - loss: 3.4367 - accuracy: 0.4250 - val_loss: 3.2580 - val_accuracy: 0.4443
# Epoch 45/50
# 175/175 [==============================] - 54s 310ms/step - loss: 3.5009 - accuracy: 0.4236 - val_loss: 3.4162 - val_accuracy: 0.3971
# Epoch 46/50
# 175/175 [==============================] - 54s 310ms/step - loss: 3.5676 - accuracy: 0.4057 - val_loss: 3.4012 - val_accuracy: 0.4271
# Epoch 47/50
# 175/175 [==============================] - 53s 300ms/step - loss: 3.4963 - accuracy: 0.4243 - val_loss: 3.2745 - val_accuracy: 0.4729
# Epoch 48/50
# 175/175 [==============================] - 54s 309ms/step - loss: 3.5591 - accuracy: 0.4200 - val_loss: 3.4727 - val_accuracy: 0.5007
# Epoch 49/50
# 175/175 [==============================] - 51s 293ms/step - loss: 3.4694 - accuracy: 0.4107 - val_loss: 3.3071 - val_accuracy: 0.4564
# Epoch 50/50
# 175/175 [==============================] - 51s 290ms/step - loss: 3.5141 - accuracy: 0.4471 - val_loss: 3.4347 - val_accuracy: 0.4700

# %%
for layer in pre_trained_model.layers:
    layer.trainable = True

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 20,289,092
# Trainable params: 20,289,092
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_val, acc_val = model.evaluate(train_data, verbose=1)
print("Validation: accuracy = %f  ;  loss_v = %f" % (acc_val, loss_val))
# Out:
# 175/175 [==============================] - 24s 129ms/step - loss: 3.4048 - accuracy: 0.4593
# Validation: accuracy = 0.459286  ;  loss_v = 3.404833

# %%
loss_test, acc_test = model.evaluate(test_data, verbose=1)
print("Test: accuracy = %f  ;  loss = %f" % (acc_test, loss_test))
# Out:
# 175/175 [==============================] - 25s 141ms/step - loss: 3.4289 - accuracy: 0.4771
# Test: accuracy = 0.477143  ;  loss = 3.428935

# %%
yTrue = test_data.classes

# %%
classes_ = ['Acne', 'Eczema', 'Melanoma', 'Psoriasis']

# Generate the confusion matrix for the model
y_pred = np.argmax(model.predict(test_data), axis=-1)
conf_mat = confusion_matrix(yTrue, y_pred, labels=range(len(classes_)))

group_names = ['True Acne','False Eczema','False Melanoma','False Psoriasis',
               'False Acne','True Eczema','False Melanoma','False Psoriasis',
               'False Acne','False Eczema','True Melanoma','False Psoriasis',
               'False Acne','False Eczema','False Melanoma','True Psoriasis']

group_counts = ["{0:0.0f}".format(value) for value in
                conf_mat.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     conf_mat.flatten()/np.sum(conf_mat)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(len(classes_),len(classes_))

ax = sns.heatmap(conf_mat, annot=labels, yticklabels=classes_, xticklabels=classes_, fmt='', cmap='OrRd')
ax.set(title='Confusion Matrix', xlabel='Predicted Diseases', ylabel='Actual Diseases')
ax.plot()
# Out:
# 175/175 [==============================] - 29s 159ms/step
# []

# %%
report = classification_report(yTrue, y_pred, target_names=classes_)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         Acne       0.26      0.69      0.38       350
#       Eczema       0.25      0.27      0.26       350
#     Melanoma       0.00      0.00      0.00       350
#    Psoriasis       0.36      0.09      0.15       350
#
#     accuracy                           0.26      1400
#    macro avg       0.22      0.26      0.20      1400
# weighted avg       0.22      0.26      0.20      1400

# %%
accuracy = history.history['accuracy']
validationAccuracy = history.history['val_accuracy']

loss = history.history['loss']
validationLoss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(epoch), accuracy, label='Training Accuracy')
plt.plot(range(epoch), validationAccuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(epoch), loss, label='Training Loss')
plt.plot(range(epoch), validationLoss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model_version=max([int(i) for i in os.listdir("../skinDiseaseDetection/models") + [1]])
model.save(f"../skinDiseaseDetection/models/{model_version}")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../skinDiseaseDetection/models/6\assets
# INFO:tensorflow:Assets written to: ../skinDiseaseDetection/models/6\assets

# %%
model.save("../modelVGG.h5")
